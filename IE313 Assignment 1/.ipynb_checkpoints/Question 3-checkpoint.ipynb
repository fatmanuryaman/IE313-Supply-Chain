# %%
from pulp import*

# %%
#Define the model.
model = LpProblem(name="IE13_Assignment1", sense = LpMaximize)

# %%
#Define the sets.
period = list(range(13))

# %%
#Define the decision variables.
X = LpVariable.dicts("Amount of Production" , (period), lowBound = 0)
I = LpVariable.dicts("Inventory Level" , (period), lowBound = 0)
W = LpVariable.dicts("Regular Time Workhours Used" , (period), lowBound = 0)
O = LpVariable.dicts("Overtime Workhours Used" , (period), lowBound = 0)

# %%
#Define the parameters.

#demand:
dt = {
    0:0,
    1:280,
    2:301,
    3:277,
    4:310*1.5+285*0.2+278*0.2,
    5:285*0.8,
    6:278*0.8,
    7:291,
    8:277,
    9:304,
    10:295,
    11:302,
    12:297,
    13:0
}
I[0] = 150
I[12] = 150

#Constant Workforce Production
#Number of employees:
ne = 100
#Manhours required to produce one unit of the product:
k = 100
#The cost per manhour of regular labor in month t:
wt = 10
#The cost per manhour overtime labor in month t:
ot = 15
#The unit production cost in month t:
vt = 1000
#The unit inventory cost in month t:
ct = 100
#The sale price
spt = {
    0:0,
    1:2600,
    2:2600,
    3:2600,
    4:2340,
    5:2600,
    6:2600,
    7:2600,
    8:2600,
    9:2600,
    10:2600,
    11:2600,
    12:2600,
    13:0
}

#The total manhours of regular labor available in month t:
rmt = 20 * 2 * 8 * ne
#The total manhours of overtime labor available in month t:
owt = 20 * 2 * ne #multplied by 2 because of 2 shifts

# %%
#Define the constraints.
for t in period[1:]:
    model += (X[t] + I[t-1] == dt[t] + I[t] , "Balance Equation %s"%t)
    model += (k*X[t] <= W[t] + O[t] , "Workhours Availability %s"%t)
    model += (W[t] == rmt , "Regular Workhour Constraint %s"%t)
    model += (O[t] <= owt , "Overtime Workhours Constraint %s"%t)
    model += (I[t] >= 100 , "Safety Stock Constraint %s"%t)
#Define the objective function.
model += lpSum(spt[t] * dt[t] - vt * X[t] - ct * I[t] - wt* W[t] - ot * O[t] for t in period[1:])

# %%
model
# Out:
# IE13_Assignment1:
# MAXIMIZE
# -1000*Amount_of_Production_1 + -1000*Amount_of_Production_10 + -1000*Amount_of_Production_11 + -1000*Amount_of_Production_12 + -1000*Amount_of_Production_2 + -1000*Amount_of_Production_3 + -1000*Amount_of_Production_4 + -1000*Amount_of_Production_5 + -1000*Amount_of_Production_6 + -1000*Amount_of_Production_7 + -1000*Amount_of_Production_8 + -1000*Amount_of_Production_9 + -100*Inventory_Level_1 + -100*Inventory_Level_10 + -100*Inventory_Level_11 + -100*Inventory_Level_2 + -100*Inventory_Level_3 + -100*Inventory_Level_4 + -100*Inventory_Level_5 + -100*Inventory_Level_6 + -100*Inventory_Level_7 + -100*Inventory_Level_8 + -100*Inventory_Level_9 + -15*Overtime_Workhours_Used_1 + -15*Overtime_Workhours_Used_10 + -15*Overtime_Workhours_Used_11 + -15*Overtime_Workhours_Used_12 + -15*Overtime_Workhours_Used_2 + -15*Overtime_Workhours_Used_3 + -15*Overtime_Workhours_Used_4 + -15*Overtime_Workhours_Used_5 + -15*Overtime_Workhours_Used_6 + -15*Overtime_Workhours_Used_7 + -15*Overtime_Workhours_Used_8 + -15*Overtime_Workhours_Used_9 + -10*Regular_Time_Workhours_Used_1 + -10*Regular_Time_Workhours_Used_10 + -10*Regular_Time_Workhours_Used_11 + -10*Regular_Time_Workhours_Used_12 + -10*Regular_Time_Workhours_Used_2 + -10*Regular_Time_Workhours_Used_3 + -10*Regular_Time_Workhours_Used_4 + -10*Regular_Time_Workhours_Used_5 + -10*Regular_Time_Workhours_Used_6 + -10*Regular_Time_Workhours_Used_7 + -10*Regular_Time_Workhours_Used_8 + -10*Regular_Time_Workhours_Used_9 + 9330024.0
# SUBJECT TO
# Balance_Equation_1: Amount_of_Production_1 - Inventory_Level_1 = 130
#
# Workhours_Availability_1: 100 Amount_of_Production_1
#  - Overtime_Workhours_Used_1 - Regular_Time_Workhours_Used_1 <= 0
#
# Regular_Workhour_Constraint_1: Regular_Time_Workhours_Used_1 = 32000
#
# Overtime_Workhours_Constraint_1: Overtime_Workhours_Used_1 <= 4000
#
# Safety_Stock_Constraint_1: Inventory_Level_1 >= 100
#
# Balance_Equation_2: Amount_of_Production_2 + Inventory_Level_1
#  - Inventory_Level_2 = 301
#
# Workhours_Availability_2: 100 Amount_of_Production_2
#  - Overtime_Workhours_Used_2 - Regular_Time_Workhours_Used_2 <= 0
#
# Regular_Workhour_Constraint_2: Regular_Time_Workhours_Used_2 = 32000
#
# Overtime_Workhours_Constraint_2: Overtime_Workhours_Used_2 <= 4000
#
# Safety_Stock_Constraint_2: Inventory_Level_2 >= 100
#
# Balance_Equation_3: Amount_of_Production_3 + Inventory_Level_2
#  - Inventory_Level_3 = 277
#
# Workhours_Availability_3: 100 Amount_of_Production_3
#  - Overtime_Workhours_Used_3 - Regular_Time_Workhours_Used_3 <= 0
#
# Regular_Workhour_Constraint_3: Regular_Time_Workhours_Used_3 = 32000
#
# Overtime_Workhours_Constraint_3: Overtime_Workhours_Used_3 <= 4000
#
# Safety_Stock_Constraint_3: Inventory_Level_3 >= 100
#
# Balance_Equation_4: Amount_of_Production_4 + Inventory_Level_3
#  - Inventory_Level_4 = 577.6
#
# Workhours_Availability_4: 100 Amount_of_Production_4
#  - Overtime_Workhours_Used_4 - Regular_Time_Workhours_Used_4 <= 0
#
# Regular_Workhour_Constraint_4: Regular_Time_Workhours_Used_4 = 32000
#
# Overtime_Workhours_Constraint_4: Overtime_Workhours_Used_4 <= 4000
#
# Safety_Stock_Constraint_4: Inventory_Level_4 >= 100
#
# Balance_Equation_5: Amount_of_Production_5 + Inventory_Level_4
#  - Inventory_Level_5 = 228
#
# Workhours_Availability_5: 100 Amount_of_Production_5
#  - Overtime_Workhours_Used_5 - Regular_Time_Workhours_Used_5 <= 0
#
# Regular_Workhour_Constraint_5: Regular_Time_Workhours_Used_5 = 32000
#
# Overtime_Workhours_Constraint_5: Overtime_Workhours_Used_5 <= 4000
#
# Safety_Stock_Constraint_5: Inventory_Level_5 >= 100
#
# Balance_Equation_6: Amount_of_Production_6 + Inventory_Level_5
#  - Inventory_Level_6 = 222.4
#
# Workhours_Availability_6: 100 Amount_of_Production_6
#  - Overtime_Workhours_Used_6 - Regular_Time_Workhours_Used_6 <= 0
#
# Regular_Workhour_Constraint_6: Regular_Time_Workhours_Used_6 = 32000
#
# Overtime_Workhours_Constraint_6: Overtime_Workhours_Used_6 <= 4000
#
# Safety_Stock_Constraint_6: Inventory_Level_6 >= 100
#
# Balance_Equation_7: Amount_of_Production_7 + Inventory_Level_6
#  - Inventory_Level_7 = 291
#
# Workhours_Availability_7: 100 Amount_of_Production_7
#  - Overtime_Workhours_Used_7 - Regular_Time_Workhours_Used_7 <= 0
#
# Regular_Workhour_Constraint_7: Regular_Time_Workhours_Used_7 = 32000
#
# Overtime_Workhours_Constraint_7: Overtime_Workhours_Used_7 <= 4000
#
# Safety_Stock_Constraint_7: Inventory_Level_7 >= 100
#
# Balance_Equation_8: Amount_of_Production_8 + Inventory_Level_7
#  - Inventory_Level_8 = 277
#
# Workhours_Availability_8: 100 Amount_of_Production_8
#  - Overtime_Workhours_Used_8 - Regular_Time_Workhours_Used_8 <= 0
#
# Regular_Workhour_Constraint_8: Regular_Time_Workhours_Used_8 = 32000
#
# Overtime_Workhours_Constraint_8: Overtime_Workhours_Used_8 <= 4000
#
# Safety_Stock_Constraint_8: Inventory_Level_8 >= 100
#
# Balance_Equation_9: Amount_of_Production_9 + Inventory_Level_8
#  - Inventory_Level_9 = 304
#
# Workhours_Availability_9: 100 Amount_of_Production_9
#  - Overtime_Workhours_Used_9 - Regular_Time_Workhours_Used_9 <= 0
#
# Regular_Workhour_Constraint_9: Regular_Time_Workhours_Used_9 = 32000
#
# Overtime_Workhours_Constraint_9: Overtime_Workhours_Used_9 <= 4000
#
# Safety_Stock_Constraint_9: Inventory_Level_9 >= 100
#
# Balance_Equation_10: Amount_of_Production_10 - Inventory_Level_10
#  + Inventory_Level_9 = 295
#
# Workhours_Availability_10: 100 Amount_of_Production_10
#  - Overtime_Workhours_Used_10 - Regular_Time_Workhours_Used_10 <= 0
#
# Regular_Workhour_Constraint_10: Regular_Time_Workhours_Used_10 = 32000
#
# Overtime_Workhours_Constraint_10: Overtime_Workhours_Used_10 <= 4000
#
# Safety_Stock_Constraint_10: Inventory_Level_10 >= 100
#
# Balance_Equation_11: Amount_of_Production_11 + Inventory_Level_10
#  - Inventory_Level_11 = 302
#
# Workhours_Availability_11: 100 Amount_of_Production_11
#  - Overtime_Workhours_Used_11 - Regular_Time_Workhours_Used_11 <= 0
#
# Regular_Workhour_Constraint_11: Regular_Time_Workhours_Used_11 = 32000
#
# Overtime_Workhours_Constraint_11: Overtime_Workhours_Used_11 <= 4000
#
# Safety_Stock_Constraint_11: Inventory_Level_11 >= 100
#
# Balance_Equation_12: Amount_of_Production_12 + Inventory_Level_11 = 447
#
# Workhours_Availability_12: 100 Amount_of_Production_12
#  - Overtime_Workhours_Used_12 - Regular_Time_Workhours_Used_12 <= 0
#
# Regular_Workhour_Constraint_12: Regular_Time_Workhours_Used_12 = 32000
#
# Overtime_Workhours_Constraint_12: Overtime_Workhours_Used_12 <= 4000
#
# VARIABLES
# Amount_of_Production_1 Continuous
# Amount_of_Production_10 Continuous
# Amount_of_Production_11 Continuous
# Amount_of_Production_12 Continuous
# Amount_of_Production_2 Continuous
# Amount_of_Production_3 Continuous
# Amount_of_Production_4 Continuous
# Amount_of_Production_5 Continuous
# Amount_of_Production_6 Continuous
# Amount_of_Production_7 Continuous
# Amount_of_Production_8 Continuous
# Amount_of_Production_9 Continuous
# Inventory_Level_1 Continuous
# Inventory_Level_10 Continuous
# Inventory_Level_11 Continuous
# Inventory_Level_2 Continuous
# Inventory_Level_3 Continuous
# Inventory_Level_4 Continuous
# Inventory_Level_5 Continuous
# Inventory_Level_6 Continuous
# Inventory_Level_7 Continuous
# Inventory_Level_8 Continuous
# Inventory_Level_9 Continuous
# Overtime_Workhours_Used_1 Continuous
# Overtime_Workhours_Used_10 Continuous
# Overtime_Workhours_Used_11 Continuous
# Overtime_Workhours_Used_12 Continuous
# Overtime_Workhours_Used_2 Continuous
# Overtime_Workhours_Used_3 Continuous
# Overtime_Workhours_Used_4 Continuous
# Overtime_Workhours_Used_5 Continuous
# Overtime_Workhours_Used_6 Continuous
# Overtime_Workhours_Used_7 Continuous
# Overtime_Workhours_Used_8 Continuous
# Overtime_Workhours_Used_9 Continuous
# Regular_Time_Workhours_Used_1 Continuous
# Regular_Time_Workhours_Used_10 Continuous
# Regular_Time_Workhours_Used_11 Continuous
# Regular_Time_Workhours_Used_12 Continuous
# Regular_Time_Workhours_Used_2 Continuous
# Regular_Time_Workhours_Used_3 Continuous
# Regular_Time_Workhours_Used_4 Continuous
# Regular_Time_Workhours_Used_5 Continuous
# Regular_Time_Workhours_Used_6 Continuous
# Regular_Time_Workhours_Used_7 Continuous
# Regular_Time_Workhours_Used_8 Continuous
# Regular_Time_Workhours_Used_9 Continuous

# %%
model.solve()
LpStatus[model.status]
# Out:
# 'Optimal'

# %%
print("Optimal objective function value = ", value(model.objective))
# Out:
# Optimal objective function value =  1521804.0

# %%
for v in model.variables():
    print(v.name, "=", v.varValue)
# Out:
# Amount_of_Production_1 = 320.0
# Amount_of_Production_10 = 304.0
# Amount_of_Production_11 = 320.0
# Amount_of_Production_12 = 320.0
# Amount_of_Production_2 = 345.6
# Amount_of_Production_3 = 360.0
# Amount_of_Production_4 = 360.0
# Amount_of_Production_5 = 228.0
# Amount_of_Production_6 = 222.4
# Amount_of_Production_7 = 291.0
# Amount_of_Production_8 = 277.0
# Amount_of_Production_9 = 304.0
# Inventory_Level_1 = 190.0
# Inventory_Level_10 = 109.0
# Inventory_Level_11 = 127.0
# Inventory_Level_2 = 234.6
# Inventory_Level_3 = 317.6
# Inventory_Level_4 = 100.0
# Inventory_Level_5 = 100.0
# Inventory_Level_6 = 100.0
# Inventory_Level_7 = 100.0
# Inventory_Level_8 = 100.0
# Inventory_Level_9 = 100.0
# Overtime_Workhours_Used_1 = 0.0
# Overtime_Workhours_Used_10 = 0.0
# Overtime_Workhours_Used_11 = 0.0
# Overtime_Workhours_Used_12 = 0.0
# Overtime_Workhours_Used_2 = 2560.0
# Overtime_Workhours_Used_3 = 4000.0
# Overtime_Workhours_Used_4 = 4000.0
# Overtime_Workhours_Used_5 = 0.0
# Overtime_Workhours_Used_6 = 0.0
# Overtime_Workhours_Used_7 = 0.0
# Overtime_Workhours_Used_8 = 0.0
# Overtime_Workhours_Used_9 = 0.0
# Regular_Time_Workhours_Used_1 = 32000.0
# Regular_Time_Workhours_Used_10 = 32000.0
# Regular_Time_Workhours_Used_11 = 32000.0
# Regular_Time_Workhours_Used_12 = 32000.0
# Regular_Time_Workhours_Used_2 = 32000.0
# Regular_Time_Workhours_Used_3 = 32000.0
# Regular_Time_Workhours_Used_4 = 32000.0
# Regular_Time_Workhours_Used_5 = 32000.0
# Regular_Time_Workhours_Used_6 = 32000.0
# Regular_Time_Workhours_Used_7 = 32000.0
# Regular_Time_Workhours_Used_8 = 32000.0
# Regular_Time_Workhours_Used_9 = 32000.0
